# %% [markdown]
# # Image Translation

# %%
import cv2
import numpy as np 
img = cv2.imread(r"C:\Users\22108160\Desktop\OIP (2).jpg")

#defining translation parameters
tx = 50
ty= 50

#performing translation
rows, cols = img.shape[:2]
translation_matrix = np.float32([[1,0,tx],[0,1,ty]])
translated_image = cv2.warpAffine(img, translation_matrix,(img.shape[1], img.shape[0]))

cv2.imshow('translated_image',translated_image)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # Image Scaling

# %%
import cv2
import matplotlib.pyplot as plt
img = cv2.imread(r"C:\Users\22108160\Desktop\5.jpg")

#defining scaling parameters
scale_x = 10
scale_y = 10

#performing scaling
scaled_img = cv2.resize(img, None, fx=scale_x, fy=scale_y)

#conveting bgr to rgb
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
scaled_img_rgb = cv2.cvtColor(scaled_img, cv2.COLOR_BGR2RGB)

#displaying the images 
plt.figure(figsize=(10,5))

#original image 
plt.subplot(1,2,1)
plt.imshow(img_rgb)
plt.title("Original Image")
plt.axis('off')

#Scaled Image 
plt.subplot(1,2,2)
plt.imshow(scaled_img_rgb)
plt.title("Scaled Image")
plt.axis('off')

plt.show()

# %% [markdown]
# # Image Rotation

# %%
import cv2
import matplotlib.pyplot as plt
img = cv2.imread(r'C:\Users\22108160\Desktop\OIP.jpg')
img = cv2.resize(img, (400,300))

#define rotation angle in degrees 
angle = 70

#perform rotation
rows, cols = img.shape[:2]
rotation_matrix = cv2.getRotationMatrix2D((cols/2, rows/2),angle,1)
rotated_image = cv2.warpAffine(img, rotation_matrix, (cols, rows))

#display rotated image 
cv2.imshow('rotated_image',rotated_image)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # Image Negative

# %%
import cv2
import matplotlib.pyplot as plt
o_img = cv2.imread(r'C:\Users\22108160\Desktop\OIP.jpg')
n_img = cv2.resize(o_img, (400,300))
n_img= cv2.cvtColor(n_img, cv2.COLOR_BGR2RGB)

#calculate negative value 
negative_img = 255 - n_img

#displaying the images 
plt.figure(figsize=(10,5))

#original image 
plt.subplot(1,2,1)
plt.imshow(n_img)
plt.title("Original Image")
plt.axis('off')

#Scaled Image 
plt.subplot(1,2,2)
plt.imshow(o_img)
plt.title("Negative Image")
plt.axis('off')

plt.show()
